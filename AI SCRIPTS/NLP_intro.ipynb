# %% [markdown]
# # Practical - 16
# # Aim - Introduction to VGG16 or Visual Geometry Group 16

# %%
import tensorflow as tf
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

# %%
sentences = [
    'i do not like dogs',
    'do you like dogs?',
    'his cat is black',
    'This white cat is very cute',
    'this is pretty sweet',
    'I am Batman',
    'i am the owner of WAYNE enterprises',
    'I also own Wayne Aerospace',
    'I am vengeance',
    'Tell me , do you bleed',
    'जीना इसी का नाम है'
]

# %%
tokenizer = Tokenizer(oov_token = "<oov>")
tokenizer.fit_on_texts(sentences)
word_index = tokenizer.word_index
print(word_index)
# Out:
# {'<oov>': 1, 'i': 2, 'do': 3, 'is': 4, 'am': 5, 'like': 6, 'dogs': 7, 'you': 8, 'cat': 9, 'this': 10, 'wayne': 11, 'not': 12, 'his': 13, 'black': 14, 'white': 15, 'very': 16, 'cute': 17, 'pretty': 18, 'sweet': 19, 'batman': 20, 'the': 21, 'owner': 22, 'of': 23, 'enterprises': 24, 'also': 25, 'own': 26, 'aerospace': 27, 'vengeance': 28, 'tell': 29, 'me': 30, 'bleed': 31, 'जीना': 32, 'इसी': 33, 'का': 34, 'नाम': 35, 'है': 36}

# %%
sequences = tokenizer.texts_to_sequences(sentences)
print(sequences[10])
# Out:
# [32, 33, 34, 35, 36]

# %%
padded = pad_sequences(sequences , padding='post')
print(padded[3])
print(padded[10])
# Out:
# [10 15  9  4 16 17  0]
# [32 33 34 35 36  0  0]
